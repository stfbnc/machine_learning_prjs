# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Bidirectional
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
temperatures = pd.read_csv('GlobalTemperatures.csv')
temperatures.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
temperatures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 9 columns):
# dt                                           3192 non-null object
# LandAverageTemperature                       3180 non-null float64
# LandAverageTemperatureUncertainty            3180 non-null float64
# LandMaxTemperature                           1992 non-null float64
# LandMaxTemperatureUncertainty                1992 non-null float64
# LandMinTemperature                           1992 non-null float64
# LandMinTemperatureUncertainty                1992 non-null float64
# LandAndOceanAverageTemperature               1992 non-null float64
# LandAndOceanAverageTemperatureUncertainty    1992 non-null float64
# dtypes: float64(8), object(1)
# memory usage: 224.5+ KB

# %%
temperatures.hist(bins=20, figsize=(12,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002623E6A2B70>,
# ...
#       dtype=object)

# %%
temperatures.dt = pd.to_datetime(temperatures.dt).dt.strftime('%Y-%m')

# %%
#check if there is some missing date
start_date = pd.to_datetime(temperatures.dt.iloc[0])
end_date = pd.to_datetime(temperatures.dt.iloc[-1]) + pd.DateOffset(months=1)
range_M = pd.date_range(start=start_date, end=end_date, freq='M')
print('Monthly period length from data = {}'.format(len(temperatures.dt)))
print('Monthly period length from calendar = {}'.format(len(range_M)))
print('Number of unique dates: {}'.format(len(temperatures.dt.unique())))
# Out:
# Monthly period length from data = 3192
# Monthly period length from calendar = 3192
# Number of unique dates: 3192

# %%
x = range(0, len(temperatures))

# %%
low_vals = temperatures.LandAverageTemperature - temperatures.LandAverageTemperatureUncertainty
upp_vals = temperatures.LandAverageTemperature + temperatures.LandAverageTemperatureUncertainty
plt.plot(x, temperatures.LandAverageTemperature)
plt.fill_between(x, low_vals, upp_vals, color='b', alpha=0.4)
plt.xticks(x[::150], temperatures.dt.iloc[::150], rotation=90)
plt.ylabel('T [$^\circ$C]')
plt.title('Average Land Temperature')
# Out:
# Text(0.5, 1.0, 'Average Land Temperature')

# %%
low_vals_min = temperatures.LandMinTemperature - temperatures.LandMinTemperatureUncertainty
upp_vals_min = temperatures.LandMinTemperature + temperatures.LandMinTemperatureUncertainty
plt.plot(x, temperatures.LandMinTemperature)
plt.fill_between(x, low_vals_min, upp_vals_min, color='b', alpha=0.4)
plt.xticks(x[::150], temperatures.dt.iloc[::150], rotation=90)
plt.ylabel('T$_{min}$ [$^\circ$C]')
plt.title('Minimum Land Temperature')
# Out:
# Text(0.5, 1.0, 'Minimum Land Temperature')

# %%
low_vals_max = temperatures.LandMaxTemperature - temperatures.LandMaxTemperatureUncertainty
upp_vals_max = temperatures.LandMaxTemperature + temperatures.LandMaxTemperatureUncertainty
plt.plot(x, temperatures.LandMaxTemperature)
plt.fill_between(x, low_vals_max, upp_vals_max, color='b', alpha=0.4)
plt.xticks(x[::150], temperatures.dt.iloc[::150], rotation=90)
plt.ylabel('T$_{max}$ [$^\circ$C]')
plt.title('Maximum Land Temperature')
# Out:
# Text(0.5, 1.0, 'Maximum Land Temperature')

# %%
low_vals_oc = temperatures.LandAndOceanAverageTemperature - temperatures.LandAndOceanAverageTemperatureUncertainty
upp_vals_oc = temperatures.LandAndOceanAverageTemperature + temperatures.LandAndOceanAverageTemperatureUncertainty
plt.plot(x, temperatures.LandAndOceanAverageTemperature)
plt.fill_between(x, low_vals_oc, upp_vals_oc, color='b', alpha=0.4)
plt.xticks(x[::150], temperatures.dt.iloc[::150], rotation=90)
plt.ylabel('T [$^\circ$C]')
plt.title('Average Land and Ocean Temperature')
# Out:
# Text(0.5, 1.0, 'Average Land and Ocean Temperature')

# %% [markdown]
# # Yearly averages

# %%
temperatures_yearly = temperatures.groupby(
    temperatures.dt.str.extract('(\d{4})', expand=False)).agg({'LandAverageTemperature': np.nanmean,
                                    'LandAverageTemperatureUncertainty': lambda v: np.sqrt(np.nansum(v**2.0))/len(v),
                                    'LandMaxTemperature': np.nanmean,
                                    'LandMaxTemperatureUncertainty': lambda v: np.sqrt(np.nansum(v**2.0))/len(v),
                                    'LandMinTemperature': np.nanmean,
                                    'LandMinTemperatureUncertainty': lambda v: np.sqrt(np.nansum(v**2.0))/len(v),
                                    'LandAndOceanAverageTemperature': np.nanmean,
                                    'LandAndOceanAverageTemperatureUncertainty': lambda v: np.sqrt(np.nansum(v**2.0))/len(v)}
                                    ).reset_index()

# %%
temperatures_yearly.head()
# Out:
#      dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750                8.719364                           0.748772
# 1  1751                7.976143                           0.630065
# 2  1752                5.779833                           0.614176
# 3  1753                8.388083                           0.970134
# 4  1754                8.469333                           1.091063
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            0.0                 NaN
# 1                 NaN                            0.0                 NaN
# 2                 NaN                            0.0                 NaN
# 3                 NaN                            0.0                 NaN
# 4                 NaN                            0.0                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
temperatures_yearly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 9 columns):
# dt                                           266 non-null object
# LandAverageTemperature                       266 non-null float64
# LandAverageTemperatureUncertainty            266 non-null float64
# LandMaxTemperature                           166 non-null float64
# LandMaxTemperatureUncertainty                266 non-null float64
# LandMinTemperature                           166 non-null float64
# LandMinTemperatureUncertainty                266 non-null float64
# LandAndOceanAverageTemperature               166 non-null float64
# LandAndOceanAverageTemperatureUncertainty    266 non-null float64
# dtypes: float64(8), object(1)
# memory usage: 18.8+ KB

# %%
x1 = range(0, len(temperatures_yearly))

# %%
#average land
low_vals = temperatures_yearly.LandAverageTemperature - temperatures_yearly.LandAverageTemperatureUncertainty
upp_vals = temperatures_yearly.LandAverageTemperature + temperatures_yearly.LandAverageTemperatureUncertainty
#min
low_vals_min = temperatures_yearly.LandMinTemperature - temperatures_yearly.LandMinTemperatureUncertainty
upp_vals_min = temperatures_yearly.LandMinTemperature + temperatures_yearly.LandMinTemperatureUncertainty
#max
low_vals_max = temperatures_yearly.LandMaxTemperature - temperatures_yearly.LandMaxTemperatureUncertainty
upp_vals_max = temperatures_yearly.LandMaxTemperature + temperatures_yearly.LandMaxTemperatureUncertainty
#average land and ocean
low_vals_oc = temperatures_yearly.LandAndOceanAverageTemperature - temperatures_yearly.LandAndOceanAverageTemperatureUncertainty
upp_vals_oc = temperatures_yearly.LandAndOceanAverageTemperature + temperatures_yearly.LandAndOceanAverageTemperatureUncertainty

plt.plot(x1, temperatures_yearly.LandAverageTemperature, label='Average Land')
plt.fill_between(x1, low_vals, upp_vals, color='b', alpha=0.4)
plt.plot(x1, temperatures_yearly.LandMaxTemperature, label='T$_{max}$')
plt.fill_between(x1, low_vals_max, upp_vals_max, color='r', alpha=0.4)
plt.plot(x1, temperatures_yearly.LandMinTemperature, label='T$_{min}$')
plt.fill_between(x1, low_vals_min, upp_vals_min, color='g', alpha=0.4)
plt.plot(x1, temperatures_yearly.LandAndOceanAverageTemperature, label='Average Land and Ocean')
plt.fill_between(x1, low_vals_oc, upp_vals_oc, color='m', alpha=0.4)
plt.xticks(x1[::10], temperatures_yearly.dt.iloc[::10], rotation=90)
plt.ylabel('T [$^\circ$C]')
plt.legend(ncol=1, loc='center left', bbox_to_anchor=(1, 0.8))
plt.title('Land Temperature')
# Out:
# Text(0.5, 1.0, 'Land Temperature')

# %%
#find starting year of the min, max and land and ocean time series
starting_year = temperatures_yearly.dropna().dt.iloc[0]
starting_idx = np.where(temperatures_yearly.dt == starting_year)[0][0]
print('Starting year: {}'.format(starting_year))
# Out:
# Starting year: 1850

# %%
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence)-1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %% [markdown]
# ### T$_{\text{min}}$

# %%
n_vals_out = 20
n_features = 1

# %%
n_steps = 10
lstm_units = 200
epochs = 500

# %%
X, y = split_sequence(temperatures_yearly.LandMinTemperature.dropna().values[:-n_vals_out], n_steps)
X = X.reshape((X.shape[0], X.shape[1], n_features))

loss = []
val_loss = []
model = Sequential()
model.add(LSTM(lstm_units, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
mod_fit = model.fit(X, y, epochs=epochs, verbose=0, validation_split=0.2, shuffle=False)
loss.append(mod_fit.history['loss'])
val_loss.append(mod_fit.history['val_loss'])

# %%
plt.plot(np.mean(loss, axis=0), label='train')
plt.plot(np.mean(val_loss, axis=0), label='validation')
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc=0)
plt.xlim(0, 80)
# Out:
# (0, 80)

# %%
tmin_forecast = []
tmin_forecast_idx = []
for i in range(-(n_steps+n_vals_out), -n_steps):
    x_input = temperatures_yearly.LandMinTemperature.dropna().values[i:i+n_steps]
    x_input = x_input.reshape((1, n_steps, n_features))
    tmin_forecast.append(model.predict(x_input, verbose=0)[0])
    tmin_forecast_idx.append(np.where(temperatures_yearly.dt == temperatures_yearly.dt.values[i+n_steps])[0][0])

# %%
plt.plot(x1, temperatures_yearly.LandMinTemperature, 'b-', label='T$_{min}$ (observed)')
plt.plot(tmin_forecast_idx, tmin_forecast, 'r-', label='T$_{min}$ (forecast)')
plt.xticks(x1[::10], temperatures_yearly.dt.iloc[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(tmin_forecast_idx[0]-10, tmin_forecast_idx[-1]+3)
# Out:
# (236, 268)

# %%
last_year = temperatures_yearly.dt.iloc[-1]
tmin_copy = list(temperatures_yearly.LandMinTemperature.dropna().values)
last_idx = len(tmin_copy)-1
pred_years = 10
years = list(temperatures_yearly.dt.iloc[starting_idx:])
for i in range(pred_years):
    years.append(str(int(last_year)+i+1))
for i in range(last_idx+1, last_idx+pred_years+1):
    x_input = np.array(tmin_copy[-n_steps:])
    x_input = x_input.reshape((1, n_steps, n_features))
    tmin_copy.append(model.predict(x_input, verbose=0)[0])

# %%
r = range(len(tmin_copy))
plt.plot(r, tmin_copy, 'b-', label='T$_{min}$')
plt.xticks(r[::10], years[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(r[0]-10, r[-1]+3)
plt.axvline(x=last_idx, color='k')

# %% [markdown]
# ### T$_{\text{max}}$

# %%
n_vals_out = 20
n_features = 1

# %%
n_steps = 10
lstm_units = 512
epochs = 500

# %%
X, y = split_sequence(temperatures_yearly.LandMaxTemperature.dropna().values[:-n_vals_out], n_steps)
X = X.reshape((X.shape[0], X.shape[1], n_features))

loss = []
val_loss = []
model = Sequential()
model.add(LSTM(lstm_units, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
mod_fit = model.fit(X, y, epochs=epochs, verbose=0, validation_split=0.2, shuffle=False)
loss.append(mod_fit.history['loss'])
val_loss.append(mod_fit.history['val_loss'])

# %%
plt.plot(np.mean(loss, axis=0), label='train')
plt.plot(np.mean(val_loss, axis=0), label='validation')
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc=0)
plt.xlim(0, 80)
# Out:
# (0, 80)

# %%
tmax_forecast = []
tmax_forecast_idx = []
for i in range(-(n_steps+n_vals_out), -n_steps):
    x_input = temperatures_yearly.LandMaxTemperature.dropna().values[i:i+n_steps]
    x_input = x_input.reshape((1, n_steps, n_features))
    tmax_forecast.append(model.predict(x_input, verbose=0)[0])
    tmax_forecast_idx.append(np.where(temperatures_yearly.dt == temperatures_yearly.dt.values[i+n_steps])[0][0])

# %%
plt.plot(x1, temperatures_yearly.LandMaxTemperature, 'b-', label='T$_{max}$ (observed)')
plt.plot(tmax_forecast_idx, tmax_forecast, 'r-', label='T$_{max}$ (forecast)')
plt.xticks(x1[::10], temperatures_yearly.dt.iloc[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(tmax_forecast_idx[0]-10, tmax_forecast_idx[-1]+3)
# Out:
# (236, 268)

# %%
last_year = temperatures_yearly.dt.iloc[-1]
tmax_copy = list(temperatures_yearly.LandMaxTemperature.dropna().values)
last_idx = len(tmax_copy)-1
pred_years = 10
years = list(temperatures_yearly.dt.iloc[starting_idx:])
for i in range(pred_years):
    years.append(str(int(last_year)+i+1))
for i in range(last_idx+1, last_idx+pred_years+1):
    x_input = np.array(tmax_copy[-n_steps:])
    x_input = x_input.reshape((1, n_steps, n_features))
    tmax_copy.append(model.predict(x_input, verbose=0)[0])

# %%
r = range(len(tmax_copy))
plt.plot(r, tmax_copy, 'b-', label='T$_{max}$')
plt.xticks(r[::10], years[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(r[0]-10, r[-1]+3)
plt.axvline(x=last_idx, color='k')

# %% [markdown]
# ### T land and ocean

# %%
n_vals_out = 20
n_features = 1

# %%
n_steps = 10
lstm_units = 512
epochs = 500

# %%
X, y = split_sequence(temperatures_yearly.LandAndOceanAverageTemperature.dropna().values[:-n_vals_out], n_steps)
X = X.reshape((X.shape[0], X.shape[1], n_features))

loss = []
val_loss = []
model = Sequential()
model.add(LSTM(lstm_units, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
mod_fit = model.fit(X, y, epochs=epochs, verbose=0, validation_split=0.2, shuffle=False)
loss.append(mod_fit.history['loss'])
val_loss.append(mod_fit.history['val_loss'])

# %%
plt.plot(np.mean(loss, axis=0), label='train')
plt.plot(np.mean(val_loss, axis=0), label='validation')
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc=0)
plt.xlim(0, 80)
# Out:
# (0, 80)

# %%
tlo_forecast = []
tlo_forecast_idx = []
for i in range(-(n_steps+n_vals_out), -n_steps):
    x_input = temperatures_yearly.LandAndOceanAverageTemperature.dropna().values[i:i+n_steps]
    x_input = x_input.reshape((1, n_steps, n_features))
    tlo_forecast.append(model.predict(x_input, verbose=0)[0])
    tlo_forecast_idx.append(np.where(temperatures_yearly.dt == temperatures_yearly.dt.values[i+n_steps])[0][0])

# %%
plt.plot(x1, temperatures_yearly.LandAndOceanAverageTemperature, 'b-', label='T (observed)')
plt.plot(tlo_forecast_idx, tlo_forecast, 'r-', label='T (forecast)')
plt.xticks(x1[::10], temperatures_yearly.dt.iloc[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(tlo_forecast_idx[0]-10, tlo_forecast_idx[-1]+3)
# Out:
# (236, 268)

# %%
last_year = temperatures_yearly.dt.iloc[-1]
tlo_copy = list(temperatures_yearly.LandAndOceanAverageTemperature.dropna().values)
last_idx = len(tlo_copy)-1
pred_years = 10
years = list(temperatures_yearly.dt.iloc[starting_idx:])
for i in range(pred_years):
    years.append(str(int(last_year)+i+1))
for i in range(last_idx+1, last_idx+pred_years+1):
    x_input = np.array(tlo_copy[-n_steps:])
    x_input = x_input.reshape((1, n_steps, n_features))
    tlo_copy.append(model.predict(x_input, verbose=0)[0])

# %%
r = range(len(tlo_copy))
plt.plot(r, tlo_copy, 'b-', label='T')
plt.xticks(r[::10], years[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(r[0]-10, r[-1]+3)
plt.axvline(x=last_idx, color='k')

# %%
X, y = split_sequence(temperatures_yearly.LandAndOceanAverageTemperature.dropna().values[:-n_vals_out], n_steps)
X = X.reshape((X.shape[0], X.shape[1], n_features))

loss = []
val_loss = []
model = Sequential()
model.add(Bidirectional(LSTM(lstm_units, activation='relu'), input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
mod_fit = model.fit(X, y, epochs=epochs, verbose=0, validation_split=0.2, shuffle=False)
loss.append(mod_fit.history['loss'])
val_loss.append(mod_fit.history['val_loss'])

# %%
plt.plot(np.mean(loss, axis=0), label='train')
plt.plot(np.mean(val_loss, axis=0), label='validation')
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc=0)
plt.xlim(0, 80)
# Out:
# (0, 80)

# %%
tlobi_forecast = []
tlobi_forecast_idx = []
for i in range(-(n_steps+n_vals_out), -n_steps):
    x_input = temperatures_yearly.LandAndOceanAverageTemperature.dropna().values[i:i+n_steps]
    x_input = x_input.reshape((1, n_steps, n_features))
    tlobi_forecast.append(model.predict(x_input, verbose=0)[0])
    tlobi_forecast_idx.append(np.where(temperatures_yearly.dt == temperatures_yearly.dt.values[i+n_steps])[0][0])

# %%
plt.plot(x1, temperatures_yearly.LandAndOceanAverageTemperature, 'b-', label='T (observed)')
plt.plot(tlobi_forecast_idx, tlobi_forecast, 'r-', label='T (forecast)')
plt.xticks(x1[::10], temperatures_yearly.dt.iloc[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(tlobi_forecast_idx[0]-10, tlobi_forecast_idx[-1]+3)
# Out:
# (236, 268)

# %%
last_year = temperatures_yearly.dt.iloc[-1]
tlobi_copy = list(temperatures_yearly.LandAndOceanAverageTemperature.dropna().values)
last_idx = len(tlobi_copy)-1
pred_years = 10
years = list(temperatures_yearly.dt.iloc[starting_idx:])
for i in range(pred_years):
    years.append(str(int(last_year)+i+1))
for i in range(last_idx+1, last_idx+pred_years+1):
    x_input = np.array(tlobi_copy[-n_steps:])
    x_input = x_input.reshape((1, n_steps, n_features))
    tlobi_copy.append(model.predict(x_input, verbose=0)[0])

# %%
r = range(len(tlobi_copy))
plt.plot(r, tlobi_copy, 'b-', label='T')
plt.xticks(r[::10], years[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(r[0]-10, r[-1]+3)
plt.axvline(x=last_idx, color='k')

# %%
X, y = split_sequence(temperatures_yearly.LandAndOceanAverageTemperature.dropna().values[:-n_vals_out], n_steps)
X = X.reshape((X.shape[0], X.shape[1], n_features))

loss = []
val_loss = []
model = Sequential()
model.add(LSTM(lstm_units, activation='relu', return_sequences=True, input_shape=(n_steps, n_features)))
model.add(LSTM(lstm_units, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
mod_fit = model.fit(X, y, epochs=epochs, verbose=0, validation_split=0.2, shuffle=False)
loss.append(mod_fit.history['loss'])
val_loss.append(mod_fit.history['val_loss'])

# %%
plt.plot(np.mean(loss, axis=0), label='train')
plt.plot(np.mean(val_loss, axis=0), label='validation')
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc=0)
plt.xlim(0, 80)
# Out:
# (0, 80)

# %%
tlostk_forecast = []
tlostk_forecast_idx = []
for i in range(-(n_steps+n_vals_out), -n_steps):
    x_input = temperatures_yearly.LandAndOceanAverageTemperature.dropna().values[i:i+n_steps]
    x_input = x_input.reshape((1, n_steps, n_features))
    tlostk_forecast.append(model.predict(x_input, verbose=0)[0])
    tlostk_forecast_idx.append(np.where(temperatures_yearly.dt == temperatures_yearly.dt.values[i+n_steps])[0][0])

# %%
plt.plot(x1, temperatures_yearly.LandAndOceanAverageTemperature, 'b-', label='T (observed)')
plt.plot(tlostk_forecast_idx, tlostk_forecast, 'r-', label='T (forecast)')
plt.xticks(x1[::10], temperatures_yearly.dt.iloc[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(tlostk_forecast_idx[0]-10, tlostk_forecast_idx[-1]+3)
# Out:
# (236, 268)

# %%
last_year = temperatures_yearly.dt.iloc[-1]
tlostk_copy = list(temperatures_yearly.LandAndOceanAverageTemperature.dropna().values)
last_idx = len(tlostk_copy)-1
pred_years = 10
years = list(temperatures_yearly.dt.iloc[starting_idx:])
for i in range(pred_years):
    years.append(str(int(last_year)+i+1))
for i in range(last_idx+1, last_idx+pred_years+1):
    x_input = np.array(tlostk_copy[-n_steps:])
    x_input = x_input.reshape((1, n_steps, n_features))
    tlostk_copy.append(model.predict(x_input, verbose=0)[0])

# %%
r = range(len(tlostk_copy))
plt.plot(r, tlostk_copy, 'b-', label='T')
plt.xticks(r[::10], years[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(r[0]-10, r[-1]+3)
plt.axvline(x=last_idx, color='k')

# %% [markdown]
# ### T land

# %%
n_vals_out = 20
n_features = 1

# %%
n_steps = 10
lstm_units = 1024
epochs = 500

# %%
X, y = split_sequence(temperatures_yearly.LandAverageTemperature.dropna().values[starting_idx:-n_vals_out], n_steps)
X = X.reshape((X.shape[0], X.shape[1], n_features))

loss = []
val_loss = []
model = Sequential()
model.add(LSTM(lstm_units, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
mod_fit = model.fit(X, y, epochs=epochs, verbose=0, validation_split=0.2, shuffle=False)
loss.append(mod_fit.history['loss'])
val_loss.append(mod_fit.history['val_loss'])

# %%
plt.plot(np.mean(loss, axis=0), label='train')
plt.plot(np.mean(val_loss, axis=0), label='validation')
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc=0)
plt.xlim(0, 80)
# Out:
# (0, 80)

# %%
tavg_forecast = []
tavg_forecast_idx = []
for i in range(-(n_steps+n_vals_out), -n_steps):
    x_input = temperatures_yearly.LandAverageTemperature.dropna().values[i:i+n_steps]
    x_input = x_input.reshape((1, n_steps, n_features))
    tavg_forecast.append(model.predict(x_input, verbose=0)[0])
    tavg_forecast_idx.append(np.where(temperatures_yearly.dt == temperatures_yearly.dt.values[i+n_steps])[0][0])

# %%
plt.plot(x1, temperatures_yearly.LandAverageTemperature, 'b-', label='T (observed)')
plt.plot(tavg_forecast_idx, tavg_forecast, 'r-', label='T (forecast)')
plt.xticks(x1[::10], temperatures_yearly.dt.iloc[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(tavg_forecast_idx[0]-10, tavg_forecast_idx[-1]+3)
# Out:
# (236, 268)

# %%
last_year = temperatures_yearly.dt.iloc[-1]
tavg_copy = list(temperatures_yearly.LandAverageTemperature.dropna().values)
last_idx = len(tavg_copy)-1
pred_years = 10
years = list(temperatures_yearly.dt)
for i in range(pred_years):
    years.append(str(int(last_year)+i+1))
for i in range(last_idx+1, last_idx+pred_years+1):
    x_input = np.array(tavg_copy[-n_steps:])
    x_input = x_input.reshape((1, n_steps, n_features))
    tavg_copy.append(model.predict(x_input, verbose=0)[0])

# %%
r = range(len(tavg_copy))
plt.plot(r, tavg_copy, 'b-', label='T')
plt.xticks(r[::10], years[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(r[0]-10, r[-1]+3)
plt.axvline(x=last_idx, color='k')

# %% [markdown]
# ### few lstm units

# %%
n_steps = 10
lstm_units = 100
epochs = 500

# %%
data = temperatures_yearly.LandAverageTemperature.dropna().values[starting_idx:]
data = data.reshape((-1,1))
split = int(0.8 * len(data))
X_train = data[:split]
X_test = data[split:]
train_generator = TimeseriesGenerator(X_train, X_train, length=n_steps, batch_size=n_features)     
test_generator = TimeseriesGenerator(X_test, X_test, length=n_steps, batch_size=n_features)

model = Sequential()
model.add(LSTM(lstm_units, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
mod_fit = model.fit_generator(train_generator, epochs=epochs, verbose=0, shuffle=False)

# %%
prediction = model.predict_generator(test_generator)

X_train = X_train.reshape((-1))
X_test = X_test.reshape((-1))
prediction = prediction.reshape((-1))

# %%
plt.plot(x1, temperatures_yearly.LandAverageTemperature.dropna().values, 'b-', label='T (observed)')
plt.plot(x1[starting_idx+split-1:starting_idx+split-1+len(prediction)], prediction, 'r-', label='T (forecast)')
plt.xticks(x1[::10], temperatures_yearly.dt.iloc[::10], rotation=90)
plt.legend(loc=0)
plt.xlim(x1[starting_idx+split-1]-10, x1[-1]+3)
# Out:
# (221, 268)

# %%
data = data.reshape((-1))

# %%
def predict(num_prediction, model):
    prediction_list = data[-n_steps:]
    
    for _ in range(num_prediction):
        x = prediction_list[-n_steps:]
        x = x.reshape((1, n_steps, 1))
        out = model.predict(x)[0][0]
        prediction_list = np.append(prediction_list, out)
    prediction_list = prediction_list[n_steps-1:]
    return prediction_list

# %%
num_prediction = 10
forecast = predict(num_prediction, model)

# %%
last_year = temperatures_yearly.dt.iloc[-1]
years = list(temperatures_yearly.dt)
for i in range(num_prediction):
    years.append(str(int(last_year)+i+1))

# %%
r = range(len(x1)+len(forecast))
plt.plot(x1, temperatures_yearly.LandAverageTemperature.dropna().values, 'b-', label='T (observed)')
plt.plot(range(x1[-1], x1[-1]+len(forecast)), forecast, 'r-', label='T (forecast)')
plt.xticks(r[::10], years[::10], rotation=90)
plt.legend(loc=0)
#plt.xlim(r[len(x1)]-10, r[-1]+3)
plt.axvline(x=x1[-1], color='k')
