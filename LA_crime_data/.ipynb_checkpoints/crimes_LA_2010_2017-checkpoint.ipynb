# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from ast import literal_eval
import mplleaflet

# %% [markdown]
# # Dataset
# ## Crimes in Los Angeles from 2010 to 2017

# %%
crime_data = pd.read_csv('Crime_Data_2010_2017.csv', header=0)

# %%
crime_data.head(3)
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0    1208575    03/14/2013    03/11/2013           1800       12  77th Street
# 1  102005556    01/25/2010    01/22/2010           2300       20      Olympic
# 2        418    03/19/2013    03/18/2013           2030       18    Southeast
#
#    Reporting District  Crime Code             Crime Code Description  \
# 0                1241         626  INTIMATE PARTNER - SIMPLE ASSAULT
# 1                2071         510                   VEHICLE - STOLEN
# 2                1823         510                   VEHICLE - STOLEN
#
#               MO Codes          ...           \
# 0  0416 0446 1243 2000          ...
# 1                  NaN          ...
# 2                  NaN          ...
#
#                                Weapon Description Status Code  \
# 0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)          AO
# 1                                             NaN          IC
# 2                                             NaN          IC
#
#   Status Description  Crime Code 1 Crime Code 2  Crime Code 3 Crime Code 4  \
# 0        Adult Other         626.0          NaN           NaN          NaN
# 1        Invest Cont         510.0          NaN           NaN          NaN
# 2        Invest Cont         510.0          NaN           NaN          NaN
#
#                                    Address Cross Street             Location
# 0  6300    BRYNHURST                    AV          NaN  (33.9829, -118.3338)
# 1                                 VAN NESS         15TH  (34.0454, -118.3157)
# 2   200 E  104TH                        ST          NaN   (33.942, -118.2717)
#
# [3 rows x 26 columns]

# %%
crime_data.columns
# Out:
# Index(['DR Number', 'Date Reported', 'Date Occurred', 'Time Occurred',
#        'Area ID', 'Area Name', 'Reporting District', 'Crime Code',
#        'Crime Code Description', 'MO Codes', 'Victim Age', 'Victim Sex',
#        'Victim Descent', 'Premise Code', 'Premise Description',
#        'Weapon Used Code', 'Weapon Description', 'Status Code',
#        'Status Description', 'Crime Code 1', 'Crime Code 2', 'Crime Code 3',
#        'Crime Code 4', 'Address', 'Cross Street', 'Location '],
#       dtype='object')

# %%
crime_data['Area Name'].unique()
# Out:
# array(['77th Street', 'Olympic', 'Southeast', 'Topanga', 'Central',
#        'Northeast', 'Foothill', 'Mission', 'Van Nuys', 'Newton',
#        'N Hollywood', 'West Valley', 'Pacific', 'Devonshire', 'Rampart',
#        'Southwest', 'Hollenbeck', 'Harbor', 'Hollywood', 'West LA',
#        'Wilshire'], dtype=object)

# %% [markdown]
# # Analysis specific to Wilshire area

# %%
whilshire = crime_data[crime_data['Area Name']=='Wilshire']

# %%
whilshire.head(3)
# Out:
#        DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 51015  130705381    02/03/2013    02/02/2013           2130        7
# 51379  130706073    02/21/2013    02/20/2013           1000        7
# 51559  130706074    02/21/2013    02/20/2013           2200        7
#
#       Area Name  Reporting District  Crime Code Crime Code Description  \
# 51015  Wilshire                 701         510       VEHICLE - STOLEN
# 51379  Wilshire                 734         510       VEHICLE - STOLEN
# 51559  Wilshire                 779         510       VEHICLE - STOLEN
#
#       MO Codes          ...           Weapon Description Status Code  \
# 51015      NaN          ...                          NaN          IC
# 51379      NaN          ...                          NaN          IC
# 51559      NaN          ...                          NaN          IC
#
#       Status Description  Crime Code 1 Crime Code 2  Crime Code 3  \
# 51015        Invest Cont         510.0          NaN           NaN
# 51379        Invest Cont         510.0          NaN           NaN
# 51559        Invest Cont         510.0          NaN           NaN
#
#       Crime Code 4                                  Address Cross Street  \
# 51015          NaN  8100    MELROSE                      AV          NaN
# 51379          NaN   500 S  CURSON                       AV          NaN
# 51559          NaN  1600    4TH                          AV          NaN
#
#                   Location
# 51015  (34.0838, -118.3659)
# 51379  (34.0657, -118.3552)
# 51559  (34.0436, -118.3213)
#
# [3 rows x 26 columns]

# %%
len(whilshire['Time Occurred'].unique())
# Out:
# 1079

# %% [markdown]
# # Number of crimes (Wilshire area)

# %%
whilshire_crm_cnt = whilshire['Crime Code Description'].dropna().value_counts()
crime_codes = np.array(whilshire_crm_cnt.index, dtype=str)
whilshire_crm_cnt = np.array(whilshire_crm_cnt, dtype=int)

# %%
plt.figure(figsize=(30,10))
plt.bar(np.arange(0, len(whilshire_crm_cnt)), whilshire_crm_cnt)
plt.xticks(np.arange(0, len(whilshire_crm_cnt)), crime_codes, rotation=90)
plt.ylabel('log(freq)')
plt.yscale('log')
plt.xlim(-1, len(whilshire_crm_cnt))
plt.title('Number of crimes in Whilshire area, LA')
# Out:
# Text(0.5,1,'Number of crimes in Whilshire area, LA')

# %%
def whilshire_crime_num(crime):
    return whilshire_crm_cnt[crime_codes==crime]

# %%
whilshire_crime_num('VEHICLE - STOLEN')
# Out:
# array([3696])

# %% [markdown]
# # Wilshire crimes grouped by night and day

# %%
crime_by_day = []
crime_by_night = []
crimes = []
for crime_code in crime_codes:
    crimes.append(crime_code)
    temp_whilshire = whilshire[whilshire['Crime Code Description']==crime_code]
    crime_by_day.append(temp_whilshire[(temp_whilshire['Time Occurred']>=600) & (temp_whilshire['Time Occurred']<=1930)].shape[0])
    crime_by_night.append(temp_whilshire[((temp_whilshire['Time Occurred']>=0) & (temp_whilshire['Time Occurred']<600)) |
                                         ((temp_whilshire['Time Occurred']>1930) & (temp_whilshire['Time Occurred']<=2359))].shape[0])
crimes = np.array(crimes, dtype=str)
crime_by_day = np.array(crime_by_day, dtype=int)
crime_by_night = np.array(crime_by_night, dtype=int)
print('Total number of crimes in Whilshire area, LA, between 2010 and 2017 -> {:d}'.format(np.sum(whilshire_crm_cnt)))
print('Total number of day crimes in Whilshire area, LA, between 2010 and 2017 -> {:d}'.format(np.sum(crime_by_day)))
print('Total number of night crimes in Whilshire area, LA, between 2010 and 2017 -> {:d}'.format(np.sum(crime_by_night)))
print('Percentage of day crimes -> {:.2f}%'.format(np.sum(crime_by_day)/np.sum(whilshire_crm_cnt)*100))
print('Percentage of night crimes -> {:.2f}%'.format(np.sum(crime_by_night)/np.sum(whilshire_crm_cnt)*100))
# Out:
# Total number of crimes in Whilshire area, LA, between 2010 and 2017 -> 63595
# Total number of day crimes in Whilshire area, LA, between 2010 and 2017 -> 42774
# Total number of night crimes in Whilshire area, LA, between 2010 and 2017 -> 20821
# Percentage of day crimes -> 67.26%
# Percentage of night crimes -> 32.74%

# %%
plt.figure(figsize=(30,10))
p1 = plt.bar(np.arange(0, len(crimes)), crime_by_night)
p2 = plt.bar(np.arange(0, len(crimes)), crime_by_day, bottom=crime_by_night)
plt.xticks(np.arange(0, len(crimes)), crimes, rotation=90)
plt.ylabel('number of crimes', fontsize=20)
plt.legend((p1[0], p2[0]), ('Night crimes (19:30 pm - 06:00 am)', 'Day crimes (06:00 am - 19:30 pm)'), fontsize=20)
#plt.yscale('log')
plt.xlim(-1, len(crimes))
plt.title('Number of day crimes in Whilshire area, LA', fontsize=20)
#plt.savefig('LA_crimes.pdf', dpi=400)
# Out:
# Text(0.5,1,'Number of day crimes in Whilshire area, LA')

# %% [markdown]
# # Number of total crimes by area

# %%
crime_area_cnt = crime_data['Area Name'].dropna().value_counts()
crime_areas = np.array(crime_area_cnt.index, dtype=str)
crime_area_cnt = np.array(crime_area_cnt, dtype=int)

# %%
plt.rc('font',family = 'serif',size = 14)
fig, ax = plt.subplots(1,1,figsize=(10,6))
bars = ax.bar(np.arange(0, len(crime_area_cnt)), crime_area_cnt, color='c')
for i, bar in enumerate(bars):
    h = bar.get_height()
    ax.text(bar.get_x()+bar.get_width()/2., 10000, '%s' % crime_areas[i], ha='center', va='bottom', rotation=90, fontsize=20)
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
#plt.xticks(np.arange(0, len(crime_area_cnt)), crime_areas, rotation=90)
#plt.ylabel('number of crimes', fontsize=20)
plt.xlim(-1, len(crime_area_cnt))
plt.title('Number of crimes by area, LA, 2010-2017', fontsize=20)
plt.tight_layout()

# %% [markdown]
# # Number of total crimes grouped by night and day

# %%
crime_area_day = []
crime_area_night = []
areas = []
for area in crime_areas:
    areas.append(area)
    temp = crime_data[crime_data['Area Name']==area]
    crime_area_day.append(temp[(temp['Time Occurred']>=600) & (temp['Time Occurred']<=1930)].shape[0])
    crime_area_night.append(temp[((temp['Time Occurred']>=0) & (temp['Time Occurred']<600)) |
                               ((temp['Time Occurred']>1930) & (temp['Time Occurred']<=2359))].shape[0])
areas = np.array(areas, dtype=str)
crime_area_day = np.array(crime_area_day, dtype=int)
crime_area_night = np.array(crime_area_night, dtype=int)
print('Total number of crimes in LA between 2010 and 2017 -> {:d}'.format(np.sum(crime_area_cnt)))
print('Total number of day crimes in LA between 2010 and 2017 -> {:d}'.format(np.sum(crime_area_day)))
print('Total number of night crimes in LA between 2010 and 2017 -> {:d}'.format(np.sum(crime_area_night)))
print('Percentage of day crimes -> {:.2f}%'.format(np.sum(crime_area_day)/np.sum(crime_area_cnt)*100))
print('Percentage of night crimes -> {:.2f}%'.format(np.sum(crime_area_night)/np.sum(crime_area_cnt)*100))
# Out:
# Total number of crimes in LA between 2010 and 2017 -> 1584316
# Total number of day crimes in LA between 2010 and 2017 -> 1018185
# Total number of night crimes in LA between 2010 and 2017 -> 566131
# Percentage of day crimes -> 64.27%
# Percentage of night crimes -> 35.73%

# %%
plt.rc('font',family = 'serif',size = 14)
fig, ax = plt.subplots(1,1,figsize=(12,6))
p1 = ax.bar(np.arange(0, len(areas)), crime_area_night, color='c')
p2 = ax.bar(np.arange(0, len(areas)), crime_area_day, bottom=crime_area_night, color='y')
for i, bar in enumerate(p1):
    h = bar.get_height()
    ax.text(bar.get_x()+bar.get_width()/2., 10000, '%s' % areas[i], ha='center', va='bottom', rotation=90, fontsize=20)
#plt.xticks(np.arange(0, len(areas)), areas, rotation=90)
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.legend((p1[0], p2[0]), ('Night crimes (19:30 pm - 06:00 am)', 'Day crimes (06:00 am - 19:30 pm)'), fontsize=20)
plt.xlim(-1, len(areas))
plt.title('Number of crimes in LA (2010-2017)', fontsize=20)
#plt.savefig('LA_crimes.pdf', dpi=400)
# Out:
# Text(0.5,1,'Number of crimes in LA (2010-2017)')

# %% [markdown]
# # Most frequent crime by area

# %%
areas = []
crime = []
crime_freq = []
for area in crime_areas:
    areas.append(area)
    temp_df = crime_data[crime_data['Area Name']==area]
    vals = temp_df.groupby('Crime Code Description').size()
    max_val = vals.max()
    crime_freq.append(max_val)
    crime.append(vals[vals==max_val].index)
areas = np.array(areas, dtype=str)
crime = np.array(crime, dtype=str)
crime_freq = np.array(crime_freq, dtype=int)

# %%
plt.rc('font',family = 'serif',size = 16)
fig, ax = plt.subplots(1,1,figsize=(8,12))
bars = ax.barh(np.arange(0, len(areas)), crime_freq, color='c', align='center')
for i, bar in enumerate(bars):
    ax.text(500, bar.get_y()+bar.get_height()/2., '%s (%d)' % (crime[i][0], crime_freq[i]), ha='left', va='center', fontsize=16)
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.yticks(np.arange(0, len(areas)), areas, fontsize=16)
plt.ylim(-0.7, len(areas)-0.3)
plt.title('Most frequent crime in LA by area (2010-2017)', fontsize=18)
# Out:
# Text(0.5,1,'Most frequent crime in LA by area (2010-2017)')

# %% [markdown]
# # Five most frequent crimes by area

# %%
crimes_num = 5
most_freq_byArea = {}
for area in crime_areas:
    most_freq_dict = {}
    temp_df = crime_data[crime_data['Area Name']==area]
    vals = temp_df.groupby('Crime Code Description').size().sort_values(ascending=False)
    for i in range(crimes_num):
        most_freq_dict[vals.index[i]] = vals[i]
    most_freq_byArea[area] = most_freq_dict

# %%
area_coords = {}
for area in crime_areas:
    temp_df = crime_data[crime_data['Area Name']==area]
    area_coords[area] = [literal_eval(x) for x in temp_df['Location '].dropna()]

# %%
mean_lat_coord = {}
mean_lon_coord = {}
for crime_area in crime_areas:
    lat_coord = np.array([area_coords[crime_area][i][0] for i in range(len(area_coords[crime_area]))], dtype=float)
    lon_coord = np.array([area_coords[crime_area][i][1] for i in range(len(area_coords[crime_area]))], dtype=float)
    lat_coord = lat_coord[lat_coord!=0]
    lon_coord = lon_coord[lon_coord!=0]
    mean_lat_coord[crime_area] = np.mean(lat_coord)
    mean_lon_coord[crime_area] = np.mean(lon_coord)

# %%
cols = ['r', 'm', 'b', 'c', 'g', 'y', 'k']
mrks = ['o', '^', 's']
fig, ax = plt.subplots(figsize=(12, 12))
for i, crime_area in enumerate(crime_areas):
    plt.scatter(mean_lon_coord[crime_area], mean_lat_coord[crime_area], c=cols[i%len(cols)], marker=mrks[i//len(cols)], s=np.max(list(most_freq_byArea[crime_area].values()))/50)
mplleaflet.display(fig=fig)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="720"></iframe>

# %%
crime_areas
# Out:
# array(['77th Street', 'Southwest', 'N Hollywood', 'Pacific', 'Southeast',
#        'Mission', 'Northeast', 'Van Nuys', 'Newton', 'Devonshire',
#        'Topanga', 'Hollywood', 'Harbor', 'Olympic', 'West Valley',
#        'Central', 'Rampart', 'West LA', 'Wilshire', 'Foothill',
#        'Hollenbeck'], dtype='<U64')

# %%
cols = ['r', 'm', 'b', 'c', 'g', 'y', 'k']
mrks = ['o', '^', 's']
fig, ax = plt.subplots(1, 1, figsize=(12, 8))
for ci, crime_area in enumerate(crime_areas):
    lat_coord = np.array([area_coords[crime_area][i][0] for i in range(len(area_coords[crime_area]))], dtype=float)
    lon_coord = np.array([area_coords[crime_area][i][1] for i in range(len(area_coords[crime_area]))], dtype=float)
    lat_coord = lat_coord[lat_coord!=0]
    lon_coord = lon_coord[lon_coord!=0]
    plt.scatter(lon_coord, lat_coord, c=cols[ci%len(cols)], marker=mrks[ci//len(cols)], label=crime_area)
plt.xlim(-119, -117.6)
plt.ylim(33.2, 35)
plt.legend(ncol=2, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
#hexagonal plot
tot_lats_lons = np.array([literal_eval(x) for x in crime_data['Location '].dropna()])
tot_lats = np.array([tot_lats_lons[i][0] for i in range(len(tot_lats_lons))], dtype=float)
tot_lons = np.array([tot_lats_lons[i][1] for i in range(len(tot_lats_lons))], dtype=float)
tot_lats = tot_lats[tot_lats!=0]
tot_lons = tot_lons[tot_lons!=0]

# %%
fig, ax = plt.subplots()
plt.hexbin(tot_lons, tot_lats, gridsize=40, cmap='Blues')
plt.xlim(np.min(tot_lons), np.max(tot_lons))
plt.ylim(np.min(tot_lats), np.max(tot_lats))
# Out:
# (33.3427, 34.7907)

# %%
# time distribution of crimes
crime_time = crime_data['Time Occurred'].dropna()
hours = 24
label = [str(i)+':00' if i//10 >= 1 else '0'+str(i)+':00' for i in range(hours+1)]
h_labels = [label[i]+' - '+label[i+1] for i in range(hours)]
h = crime_time.plot(kind='hist', bins=hours, title='Crimes by hour', rot=90, figsize=(10, 6))
h.set_xticks(np.arange(49, 2400, 100))
h.set_xticklabels(h_labels)
h.set_xlim(0, 2400)
# Out:
# (0, 2400)

# %%
#victim age
ages = crime_data['Victim Age'].dropna().unique()
ages
# Out:
# array([30., 12., 84., 49., 27., 42., 29., 19., 23., 39., 18., 25., 34.,
#        37., 50., 20., 32., 24., 48., 45., 60., 40., 46., 22., 53., 36.,
#        57., 56., 26., 52., 33., 21., 59., 28., 35., 51., 41., 11., 10.,
#        31., 43., 38., 73., 58., 70., 62., 55., 13., 66., 15., 68., 61.,
#        63., 54., 69., 44., 47., 14., 64., 93., 72., 65., 92., 75., 88.,
#        97., 82., 17., 16., 81., 74., 67., 71., 83., 77., 78., 80., 76.,
#        99., 89., 79., 86., 94., 90., 85., 95., 91., 87., 96., 98.])

# %%
crimes = crime_data['Crime Code Description'].dropna().unique()
crimes
# Out:
# array(['INTIMATE PARTNER - SIMPLE ASSAULT', 'VEHICLE - STOLEN',
#        'VANDALISM - MISDEAMEANOR ($399 OR UNDER)', 'CRIMINAL HOMICIDE',
#        'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)',
#        'THEFT PLAIN - PETTY ($950 & UNDER)', 'STALKING',
#        'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#        'BATTERY - SIMPLE ASSAULT',
#        'EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)',
#        'DOCUMENT FORGERY / STOLEN FELONY', 'BIKE - STOLEN', 'ROBBERY',
#        'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH 0007=02',
#        'ATTEMPTED ROBBERY', 'RESISTING ARREST', 'TRESPASSING',
#        'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD0036',
#        'COUNTERFEIT', 'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#        'THROWING OBJECT AT MOVING VEHICLE',
#        'DEFRAUDING INNKEEPER/THEFT OF SERVICES, $400 & UNDER',
#        'CRIMINAL THREATS - NO WEAPON DISPLAYED',
#        'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS) 0114',
#        'BURGLARY FROM VEHICLE', 'BATTERY WITH SEXUAL CONTACT',
#        'OTHER MISCELLANEOUS CRIME', 'BURGLARY',
#        'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)',
#        'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT', 'INDECENT EXPOSURE',
#        'CHILD NEGLECT (SEE 300 W.I.C.)', 'OTHER ASSAULT', 'THEFT, PERSON',
#        'BOMB SCARE', 'EXTORTION', 'RAPE, FORCIBLE',
#        'THEFT PLAIN - ATTEMPT',
#        'THEFT FROM MOTOR VEHICLE - GRAND ($400 AND OVER)',
#        'INTIMATE PARTNER - AGGRAVATED ASSAULT', 'DISTURBING THE PEACE',
#        'CHILD ANNOYING (17YRS & UNDER)',
#        'SHOTS FIRED AT INHABITED DWELLING', 'BATTERY POLICE (SIMPLE)',
#        'BRANDISH WEAPON', 'CRUELTY TO ANIMALS',
#        'SEXUAL PENTRATION WITH A FOREIGN OBJECT', 'THEFT OF IDENTITY',
#        'ARSON', 'BURGLARY, ATTEMPTED',
#        'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#        'VIOLATION OF COURT ORDER', 'LETTERS, LEWD',
#        'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)0060',
#        'BURGLARY FROM VEHICLE, ATTEMPTED', 'FALSE IMPRISONMENT',
#        'BUNCO, GRAND THEFT', 'PURSE SNATCHING',
#        'VIOLATION OF RESTRAINING ORDER', 'RAPE, ATTEMPTED',
#        'BUNCO, PETTY THEFT', 'KIDNAPPING', 'LEWD CONDUCT', 'PROWLER',
#        'VEHICLE - ATTEMPT STOLEN', 'PIMPING',
#        'BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT WITH ANIM0065',
#        'PEEPING TOM', 'SEX, UNLAWFUL', 'BIKE - ATTEMPTED STOLEN',
#        'THEFT FROM PERSON - ATTEMPT', 'PICKPOCKET', 'RECKLESS DRIVING',
#        'ORAL COPULATION', 'THREATENING PHONE CALLS/LETTERS',
#        'DISHONEST EMPLOYEE - PETTY THEFT', 'UNAUTHORIZED COMPUTER ACCESS',
#        'DISCHARGE FIREARMS/SHOTS FIRED', 'CHILD STEALING',
#        'CREDIT CARDS, FRAUD USE ($950.01 & OVER)',
#        'DRIVING WITHOUT OWNER CONSENT (DWOC)', 'BUNCO, ATTEMPT',
#        'BRIBERY', 'CREDIT CARDS, FRAUD USE ($950 & UNDER',
#        'WEAPONS POSSESSION/BOMBING',
#        'CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT',
#        'ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER',
#        'SHOPLIFTING - ATTEMPT', 'ILLEGAL DUMPING',
#        'KIDNAPPING - GRAND ATTEMPT', 'PICKPOCKET, ATTEMPT',
#        'PURSE SNATCHING - ATTEMPT', 'THEFT FROM MOTOR VEHICLE - ATTEMPT',
#        'BATTERY ON A FIREFIGHTER', 'DOCUMENT WORTHLESS ($200.01 & OVER)',
#        'FAILURE TO YIELD', 'VIOLATION OF TEMPORARY RESTRAINING ORDER',
#        'FALSE POLICE REPORT', 'DISHONEST EMPLOYEE - GRAND THEFT',
#        'ABORTION/ILLEGAL', 'CONTRIBUTING',
#        'DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $400', 'DRUNK ROLL',
#        'THEFT, COIN MACHINE - PETTY ($950 & UNDER)', 'BOAT - STOLEN',
#        'DISRUPT SCHOOL', 'INCITING A RIOT', 'FAILURE TO DISPERSE',
#        'PANDERING', 'TILL TAP - PETTY ($950 & UNDER)',
#        'LYNCHING - ATTEMPTED', 'CONSPIRACY',
#        'REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR DISTRIBUTE)0132',
#        'CHILD ABANDONMENT', 'TELEPHONE PROPERTY - DAMAGE',
#        'CONTEMPT OF COURT', 'DRUGS, TO A MINOR',
#        'SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT',
#        'GRAND THEFT / INSURANCE FRAUD',
#        'THEFT, COIN MACHINE - GRAND ($950.01 & OVER)',
#        'GRAND THEFT / AUTO REPAIR', 'PETTY THEFT - AUTO REPAIR',
#        'LYNCHING', 'MANSLAUGHTER, NEGLIGENT', 'BIGAMY',
#        'TILL TAP - ATTEMPT', 'TILL TAP - GRAND THEFT ($950.01 & OVER)',
#        'DRUNK ROLL - ATTEMPT', 'THEFT, COIN MACHINE - ATTEMPT',
#        'DOCUMENT WORTHLESS ($200 & UNDER)',
#        'DISHONEST EMPLOYEE ATTEMPTED THEFT',
#        'INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)',
#        'BLOCKING DOOR INDUCTION CENTER', 'TRAIN WRECKING'], dtype=object)

# %%
def victimsAgesByCrime(crime):
    tmp = crime_data[crime_data['Crime Code Description']==crime]
    victim_ages = tmp.fillna(0).groupby('Victim Age').size().sort_values(ascending=False)
    try:
        victim_ages = victim_ages.drop(labels=[0.0])
    except:
        pass
    return victim_ages

# %%
victimsAgesByCrime('')
# Out:
# Series([], dtype: int64)

# %%
#victim sex
sexes = crime_data['Victim Sex'].dropna().unique()
sexes
# Out:
# array(['F', 'M', 'H', 'X', '-'], dtype=object)

# %%
def victimsSexByCrime(crime):
    tmp = crime_data[crime_data['Crime Code Description']==crime]
    victim_sexes = tmp.fillna(0).groupby('Victim Sex').size().sort_values(ascending=False)
    try:
        victim_sexes = victim_sexes.drop(labels=[0])
    except:
        pass
    return victim_sexes

# %%
victimsSexByCrime('')
# Out:
# Series([], dtype: int64)

# %%
#victim descent
descents = crime_data['Victim Descent'].dropna().unique()
descents
# Out:
# array(['W', 'O', 'H', 'B', 'A', 'X', 'F', 'I', 'K', 'G', 'C', 'J', 'Z',
#        'P', 'V', 'U', 'L', 'S', 'D', '-'], dtype=object)

# %%
def victimsDescentByCrime(crime):
    tmp = crime_data[crime_data['Crime Code Description']==crime]
    victim_descents = tmp.fillna(0).groupby('Victim Descent').size().sort_values(ascending=False)
    try:
        victim_descents = victim_descents.drop(labels=[0])
    except:
        pass
    return victim_descents

# %%
victimsDescentByCrime('')
# Out:
# Series([], dtype: int64)
