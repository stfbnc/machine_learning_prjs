# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
crime_data = pd.read_csv('Crime_Data_2010_2017.csv', header=0)

# %%
crime_data.head(10)
# Out:
#    DR Number Date Reported Date Occurred  Time Occurred  Area ID    Area Name  \
# 0    1208575    03/14/2013    03/11/2013           1800       12  77th Street
# 1  102005556    01/25/2010    01/22/2010           2300       20      Olympic
# 2        418    03/19/2013    03/18/2013           2030       18    Southeast
# 3  101822289    11/11/2010    11/10/2010           1800       18    Southeast
# 4   42104479    01/11/2014    01/04/2014           2300       21      Topanga
# 5  120125367    01/08/2013    01/08/2013           1400        1      Central
# 6  101105609    01/28/2010    01/27/2010           2230       11    Northeast
# 7  101620051    11/11/2010    11/07/2010           1600       16     Foothill
# 8  101910498    04/07/2010    04/07/2010           1600       19      Mission
# 9  120908292    03/29/2013    01/15/2013            800        9     Van Nuys
#
#    Reporting District  Crime Code                      Crime Code Description  \
# 0                1241         626           INTIMATE PARTNER - SIMPLE ASSAULT
# 1                2071         510                            VEHICLE - STOLEN
# 2                1823         510                            VEHICLE - STOLEN
# 3                1803         510                            VEHICLE - STOLEN
# 4                2133         745    VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 5                 111         110                           CRIMINAL HOMICIDE
# 6                1125         510                            VEHICLE - STOLEN
# 7                1641         510                            VEHICLE - STOLEN
# 8                1902         510                            VEHICLE - STOLEN
# 9                 904         668  EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
#
#                              MO Codes          ...           \
# 0                 0416 0446 1243 2000          ...
# 1                                 NaN          ...
# 2                                 NaN          ...
# 3                                 NaN          ...
# 4                                0329          ...
# 5  1243 2000 1813 1814 2002 0416 0400          ...
# 6                                 NaN          ...
# 7                                 NaN          ...
# 8                                 NaN          ...
# 9                           0344 1300          ...
#
#                                Weapon Description Status Code  \
# 0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)          AO
# 1                                             NaN          IC
# 2                                             NaN          IC
# 3                                             NaN          IC
# 4                                             NaN          IC
# 5  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)          AA
# 6                                             NaN          IC
# 7                                             NaN          IC
# 8                                             NaN          IC
# 9                                             NaN          IC
#
#   Status Description  Crime Code 1 Crime Code 2  Crime Code 3 Crime Code 4  \
# 0        Adult Other         626.0          NaN           NaN          NaN
# 1        Invest Cont         510.0          NaN           NaN          NaN
# 2        Invest Cont         510.0          NaN           NaN          NaN
# 3        Invest Cont         510.0          NaN           NaN          NaN
# 4        Invest Cont         745.0          NaN           NaN          NaN
# 5       Adult Arrest         110.0          NaN           NaN          NaN
# 6        Invest Cont         510.0          NaN           NaN          NaN
# 7        Invest Cont         510.0          NaN           NaN          NaN
# 8        Invest Cont         510.0          NaN           NaN          NaN
# 9        Invest Cont         668.0          NaN           NaN          NaN
#
#                                    Address Cross Street             Location
# 0  6300    BRYNHURST                    AV          NaN  (33.9829, -118.3338)
# 1                                 VAN NESS         15TH  (34.0454, -118.3157)
# 2   200 E  104TH                        ST          NaN   (33.942, -118.2717)
# 3                                     88TH         WALL  (33.9572, -118.2717)
# 4  7200    CIRRUS                       WY          NaN  (34.2009, -118.6369)
# 5   600 N  HILL                         ST          NaN  (34.0591, -118.2412)
# 6                                     YORK    AVENUE 51  (34.1211, -118.2048)
# 7                                EL DORADO    TRUESDALE   (34.241, -118.3987)
# 8                                 GLENOAKS        DRELL  (34.3147, -118.4589)
# 9  7200    SEPULVEDA                    BL          NaN  (34.2012, -118.4662)
#
# [10 rows x 26 columns]

# %%
crime_data.columns
# Out:
# Index(['DR Number', 'Date Reported', 'Date Occurred', 'Time Occurred',
#        'Area ID', 'Area Name', 'Reporting District', 'Crime Code',
#        'Crime Code Description', 'MO Codes', 'Victim Age', 'Victim Sex',
#        'Victim Descent', 'Premise Code', 'Premise Description',
#        'Weapon Used Code', 'Weapon Description', 'Status Code',
#        'Status Description', 'Crime Code 1', 'Crime Code 2', 'Crime Code 3',
#        'Crime Code 4', 'Address', 'Cross Street', 'Location '],
#       dtype='object')

# %%
crime_data['Area Name'].unique()
# Out:
# array(['77th Street', 'Olympic', 'Southeast', 'Topanga', 'Central',
#        'Northeast', 'Foothill', 'Mission', 'Van Nuys', 'Newton',
#        'N Hollywood', 'West Valley', 'Pacific', 'Devonshire', 'Rampart',
#        'Southwest', 'Hollenbeck', 'Harbor', 'Hollywood', 'West LA',
#        'Wilshire'], dtype=object)

# %%
whilshire = crime_data[crime_data['Area Name']=='Wilshire']

# %%
whilshire.head(10)
# Out:
#        DR Number Date Reported Date Occurred  Time Occurred  Area ID  \
# 51015  130705381    02/03/2013    02/02/2013           2130        7
# 51379  130706073    02/21/2013    02/20/2013           1000        7
# 51559  130706074    02/21/2013    02/20/2013           2200        7
# 51600  130700537    02/05/2013    02/05/2013           1513        7
# 51643  130711608    06/24/2013    06/23/2013           1600        7
# 51666  130700001    04/03/2013    04/02/2013           1900        7
# 51667  130700002    04/14/2013    04/13/2013           2330        7
# 51668  130700510    01/08/2013    01/07/2013           1600        7
# 51669  130700512    01/12/2013    01/12/2013            430        7
# 51670  130700513    01/13/2013    01/12/2013           1845        7
#
#       Area Name  Reporting District  Crime Code  \
# 51015  Wilshire                 701         510
# 51379  Wilshire                 734         510
# 51559  Wilshire                 779         510
# 51600  Wilshire                 706         310
# 51643  Wilshire                 706         510
# 51666  Wilshire                 705         510
# 51667  Wilshire                 759         510
# 51668  Wilshire                 734         626
# 51669  Wilshire                 775         626
# 51670  Wilshire                 763         930
#
#                        Crime Code Description  \
# 51015                        VEHICLE - STOLEN
# 51379                        VEHICLE - STOLEN
# 51559                        VEHICLE - STOLEN
# 51600                                BURGLARY
# 51643                        VEHICLE - STOLEN
# 51666                        VEHICLE - STOLEN
# 51667                        VEHICLE - STOLEN
# 51668       INTIMATE PARTNER - SIMPLE ASSAULT
# 51669       INTIMATE PARTNER - SIMPLE ASSAULT
# 51670  CRIMINAL THREATS - NO WEAPON DISPLAYED
#
#                                  MO Codes          ...           \
# 51015                                 NaN          ...
# 51379                                 NaN          ...
# 51559                                 NaN          ...
# 51600                                0344          ...
# 51643                                 NaN          ...
# 51666                                 NaN          ...
# 51667                                 NaN          ...
# 51668  0400 2000 1814 0416 1243 1414 2007          ...
# 51669                                2000          ...
# 51670  0421 0445 1243 2000 1414 1821 1402          ...
#
#                                    Weapon Description Status Code  \
# 51015                                             NaN          IC
# 51379                                             NaN          IC
# 51559                                             NaN          IC
# 51600                                             NaN          AA
# 51643                                             NaN          IC
# 51666                                             NaN          IC
# 51667                                             NaN          IC
# 51668  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)          AA
# 51669  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)          IC
# 51670                                   VERBAL THREAT          AA
#
#       Status Description  Crime Code 1 Crime Code 2  Crime Code 3  \
# 51015        Invest Cont         510.0          NaN           NaN
# 51379        Invest Cont         510.0          NaN           NaN
# 51559        Invest Cont         510.0          NaN           NaN
# 51600       Adult Arrest         310.0          NaN           NaN
# 51643        Invest Cont         510.0          NaN           NaN
# 51666        Invest Cont         510.0          NaN           NaN
# 51667        Invest Cont         510.0          NaN           NaN
# 51668       Adult Arrest         626.0          NaN           NaN
# 51669        Invest Cont         626.0          NaN           NaN
# 51670       Adult Arrest         930.0        998.0           NaN
#
#       Crime Code 4                                  Address Cross Street  \
# 51015          NaN  8100    MELROSE                      AV          NaN
# 51379          NaN   500 S  CURSON                       AV          NaN
# 51559          NaN  1600    4TH                          AV          NaN
# 51600          NaN   700 N  HIGHLAND                     AV          NaN
# 51643          NaN   500 N  ORANGE                       DR          NaN
# 51666          NaN  7200    WILLOUGHBY                   AV          NaN
# 51667          NaN  3500 W  PICO                         BL          NaN
# 51668          NaN   300    HAUSER                       BL          NaN
# 51669          NaN  4600    PICKFORD                     ST          NaN
# 51670          NaN  1500 S  OGDEN                        DR          NaN
#
#                   Location
# 51015  (34.0838, -118.3659)
# 51379  (34.0657, -118.3552)
# 51559  (34.0436, -118.3213)
# 51600  (34.0835, -118.3386)
# 51643  (34.0803, -118.3416)
# 51666  (34.0871, -118.3462)
# 51667  (34.0472, -118.3189)
# 51668  (34.0699, -118.3511)
# 51669  (34.0405, -118.3395)
# 51670   (34.0493, -118.365)
#
# [10 rows x 26 columns]

# %%
whilshire_crm_cd = whilshire['Crime Code Description'].dropna().unique()
whilshire_crm_cd = np.array(whilshire_crm_cd, dtype=str)
len(whilshire_crm_cd)
# Out:
# 113

# %%
whilshire_crm_cnt = whilshire['Crime Code Description'].dropna().value_counts()
whilshire_crm_cnt = np.array(whilshire_crm_cnt, dtype=int)
len(whilshire_crm_cnt)
# Out:
# 113

# %%
plt.figure(figsize=(30,10))
plt.bar(np.arange(0, len(whilshire_crm_cnt)), whilshire_crm_cnt)
plt.xticks(np.arange(0, len(whilshire_crm_cnt)), whilshire_crm_cd, rotation=90)
plt.ylabel('log(freq)')
plt.yscale('log')
plt.xlim(-1, len(whilshire_crm_cd))
plt.title('Number of crimes in Whilshire area, LA')
# Out:
# Text(0.5,1,'Number of crimes in Whilshire area, LA')

# %%
def whilshire_crime_num(crime):
    return whilshire_crm_cnt[whilshire_crm_cd==crime]

# %%
whilshire_crime_num('VEHICLE - STOLEN')
# Out:
# array([6184])

# %%
crime_by_day = []
crime_by_night = []
for crime in whilshire_crm_cd:
    temp_whilshire = whilshire[whilshire['Crime Code Description']==crime]
    crime_by_day.append(temp_whilshire[(temp_whilshire['Time Occurred']>=600) & (temp_whilshire['Time Occurred']<=1930)].shape[0])
    crime_by_night.append(temp_whilshire[((temp_whilshire['Time Occurred']>=0) & (temp_whilshire['Time Occurred']<600)) |
                                         ((temp_whilshire['Time Occurred']>1930) & (temp_whilshire['Time Occurred']<=2359))].shape[0])
crime_by_day = np.array(crime_by_day, dtype=int)
crime_by_night = np.array(crime_by_night, dtype=int)
print('Total number of crimes in Whilshire area, LA, between 2010 and 2017 -> {:d}'.format(np.sum(whilshire_crm_cnt)))
print('Total number of day crimes in Whilshire area, LA, between 2010 and 2017 -> {:d}'.format(np.sum(crime_by_day)))
print('Total number of night crimes in Whilshire area, LA, between 2010 and 2017 -> {:d}'.format(np.sum(crime_by_night)))
print('Percentage of day crimes -> {:.2f}%'.format(np.sum(crime_by_day)/np.sum(whilshire_crm_cnt)*100))
print('Percentage of night crimes -> {:.2f}%'.format(np.sum(crime_by_night)/np.sum(whilshire_crm_cnt)*100))
# Out:
# Total number of crimes in Whilshire area, LA, between 2010 and 2017 -> 63595
# Total number of day crimes in Whilshire area, LA, between 2010 and 2017 -> 42774
# Total number of night crimes in Whilshire area, LA, between 2010 and 2017 -> 20821
# Percentage of day crimes -> 67.26%
# Percentage of night crimes -> 32.74%

# %%
plt.figure(figsize=(30,10))
p1 = plt.bar(np.arange(0, len(whilshire_crm_cd)), crime_by_night)
p2 = plt.bar(np.arange(0, len(whilshire_crm_cd)), crime_by_day, bottom=crime_by_night)
plt.xticks(np.arange(0, len(whilshire_crm_cd)), whilshire_crm_cd, rotation=90)
plt.ylabel('log(freq)')
plt.legend((p1[0], p2[0]), ('Night crimes (19:30 pm - 06:00 am)', 'Day crimes (06:00 am - 19:30 pm)'))
#plt.yscale('log')
plt.xlim(-1, len(whilshire_crm_cd))
plt.title('Number of day crimes in Whilshire area, LA')
# Out:
# Text(0.5,1,'Number of day crimes in Whilshire area, LA')

# %%
crime_area = crime_data['Area Name'].dropna().unique()
crime_area = np.array(crime_area, dtype=str)
len(crime_area)
# Out:
# 21

# %%
crime_area_cnt = crime_data['Area Name'].dropna().value_counts()
crime_area_cnt = np.array(crime_area_cnt, dtype=int)
len(crime_area_cnt)
# Out:
# 21
